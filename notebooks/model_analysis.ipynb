# %% [markdown]
# # 📊 AI Edge Allocator - Model Analysis
#
# Comprehensive analysis of DQN, PPO, and Hybrid models.
#
# ## Results Summary
# - **DQN**: 244.15 ± 9.20 (10K steps)
# - **PPO**: 241.87 ± 11.84 (10K steps)
# - **Hybrid (Best)**: 246.02 ± 8.57 (5K steps) 🏆
# - **Hybrid (Final)**: 242.64 ± 10.12 (20K steps)

# %%
# Import libraries
import sys
sys.path.append('..')

from src.analysis.model_comparison import ModelAnalyzer
from src.analysis.network_visualization import NetworkVisualizer

# %% [markdown]
# ## 1. Model Performance Analysis

# %%
# Run performance analysis
analyzer = ModelAnalyzer()
results_df = analyzer.run_full_analysis()

# %% [markdown]
# ## 2. Network Topology Visualization

# %%
# Visualize network
visualizer = NetworkVisualizer()
visualizer.run_full_visualization()

# %% [markdown]
# ## 3. Results DataFrame

# %%
# Display results table
results_df
